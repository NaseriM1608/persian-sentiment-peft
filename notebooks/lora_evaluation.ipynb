# %%
# !python src/evaluation/evaluate.py
# Out:
# config.json: 100% 440/440 [00:00<00:00, 2.04MB/s]
# ...
# vocab.txt: 1.20MB [00:00, 37.5MB/s]
# adapter_config.json: 1.04kB [00:00, 635kB/s]
# pytorch_model.bin: 100% 654M/654M [00:04<00:00, 148MB/s]
# model.safetensors:   0% 0.00/654M [00:00<?, ?B/s]
# Loading weights:   0% 0/199 [00:00<?, ?it/s]
# Loading weights:   1% 1/199 [00:00<00:00, 10082.46it/s, Materializing param=bert.embeddings.LayerNorm.bias]
# Loading weights:   1% 1/199 [00:00<00:00, 4760.84it/s, Materializing param=bert.embeddings.LayerNorm.bias]
# Loading weights:   1% 2/199 [00:00<00:00, 4639.72it/s, Materializing param=bert.embeddings.LayerNorm.weight]
# Loading weights:   1% 2/199 [00:00<00:00, 3729.93it/s, Materializing param=bert.embeddings.LayerNorm.weight]
# Loading weights:   2% 3/199 [00:00<00:00, 4022.67it/s, Materializing param=bert.embeddings.position_embeddings.weight]
# Loading weights:   2% 3/199 [00:00<00:00, 3530.56it/s, Materializing param=bert.embeddings.position_embeddings.weight]
# ...
